# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import numpy as np
import pandas as pd
from nilearn import image
from nilearn import datasets
from nilearn.plotting import plot_roi


import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
dataset = datasets.fetch_atlas_harvard_oxford('cort-maxprob-thr25-2mm', data_dir='../data/nilearn/')
atlas_filename = dataset.maps

print('Atlas ROIs are located at: %s' % atlas_filename)
# Out:
# Atlas ROIs are located at: ../data/nilearn/fsl/data/atlases/HarvardOxford/HarvardOxford-cort-maxprob-thr25-2mm.nii.gz

# %%
fig = plt.figure(figsize=(8,8))
plot_roi(atlas_filename, title="Harvard Oxford atlas")
plt.show()
